# %% [markdown]
# # Week 1 Problem Set
# ## Homework

# %%
# %load_ext nb_mypy
# %nb_mypy Off
# Out:
# Version 1.0.6

# %% [markdown]
# **HW0-a**. Reorder the code to check if a string is a palindrome.
#
# [Click here to do the Parson Problem for Palindrome problem](https://data-driven-world.github.io/hosting-parsons-on-github-template/week1#palindrome) or run the cell below.

# %%
from IPython.display import IFrame
IFrame('https://data-driven-world.github.io/hosting-parsons-on-github-template/week1#palindrome', width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://data-driven-world.github.io/hosting-parsons-on-github-template/week1#palindrome"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# **HW0-b.** Write a function `palindrome(s)`to check if the string `s` is a [Palindrome](https://en.wikipedia.org/wiki/Palindrome). Use iteration for this solution.

# %%
def palindrome(s: str) -> bool:
    ###
    for index in range( len(s) // 2 ):
        if(s[index] != s[len(s) - index - 1]):
            return False
    
    return True 
    ###

# %%
assert not palindrome("moon") 
assert palindrome("noon") 
assert palindrome("a a") 
assert palindrome("ada") 
assert not palindrome("ad a")

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# **HW-1-a.** Reorder the correct sequence of code to implement bubble sort algorithm version 2. You can check the pseudocode in [Bubble Sort and Insertion Sort](https://data-driven-world.github.io/2023/notes/sorting-algorithms/bubble-sort).
#
# The function should ...
#
# - **modify/mutate** an existing array into a sorted one
# - **return** the number of comparisons made
#
# Hint: To count the number of comparisons made you can simply increment an integer variable (counter) right before the `if` statement.
#
# [Click here to do the Parson Problem for Bubble Sort V2](https://data-driven-world.github.io/hosting-parsons-on-github-template/week1#bubblev2) or run the cell below.

# %%
IFrame('https://data-driven-world.github.io/hosting-parsons-on-github-template/week1#bubblev2', width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://data-driven-world.github.io/hosting-parsons-on-github-template/week1#bubblev2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# **HW1-b.** Create a function to implement **Bubble Sort Algorithm version 2**.

# %%
def bubble_sort(array: list[int|float]) -> int:
    count: int = 0
    ###
    n = len(array)
    swapped = True
    while( swapped == True ):
        swapped = False
        for inner_index in range(1, n):
            first_number = array[inner_index - 1]
            second_number = array[inner_index]
            count += 1
            
            if( first_number > second_number ):
                array[inner_index], array[inner_index - 1] = array[inner_index - 1], array[inner_index]
                swapped = True
    ###
    return count

# %%
array: list[int|float] = [-5,10,3,8,47,1,0,-39,8,4,7,6]
count: int = bubble_sort(array)
print(array, count)
assert array == [-39, -5, 0, 1, 3, 4, 6, 7, 8, 8, 10, 47]
assert count == 88
# Out:
# [-39, -5, 0, 1, 3, 4, 6, 7, 8, 8, 10, 47] 88

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# **HW2.** The solution in HW1 can be improved!
#
# The n-th pass places the n-th largest element into its final place (i.e. after 1 cycle, the (1st) largest element will be in its correct position).
#
# Hence, we can reduce subsequent iterations by only considering the other (unsorted) `n-1` elements in the array.
#
# Implement the algorithm of **Bubble Sort version 4** under [Bubble Sort and Insertion Sort](https://data-driven-world.github.io/2023/notes/sorting-algorithms/bubble-sort).

# %%
def bubble_sort(array: list[int|float]) -> int:
    count: int = 0
    ###
    n = len(array)
    swapped = True
    while( swapped == True ):
        swapped = False
        new_n = 0
        for inner_index in range(1, n):
            first_number = array[inner_index - 1]
            second_number = array[inner_index]
            count += 1
            
            if first_number > second_number:
                array[inner_index], array[inner_index - 1] = array[inner_index - 1], array[inner_index]
                swapped = True
                
                new_n = inner_index # note the last swap location
        n = new_n
    ###
    return count

# %%
array: list[int|float] = [10,3,8,47,1,0,-39,8,4,7,6,-5]
count: int = bubble_sort(array)
print(array, count)
assert array == [-39, -5, 0, 1, 3, 4, 6, 7, 8, 8, 10, 47]
assert count == 66
# Out:
# [-39, -5, 0, 1, 3, 4, 6, 7, 8, 8, 10, 47] 66

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###
